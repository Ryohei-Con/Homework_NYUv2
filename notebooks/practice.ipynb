# %%
from PIL import Image
from transformers import SegformerConfig, SegformerForSemanticSegmentation, SegformerModel
import torch
import numpy as np
import torch.nn as nn

# %%
image = torch.Tensor(np.array(Image.open("./data/train/image/000002.png")))
image.size()
# Out:
# torch.Size([480, 640, 3])

# %%
image_size = image.size()
patch_size = (12, 16)
mean = image.mean()
image_size[0]

# %%
encoder_model="nvidia/segformer-b0-finetuned-ade-512-512"
encoder = SegformerModel.from_pretrained(
    encoder_model
)
encoder()

# %%
import datetime

dt_now = datetime.datetime.now()
print(str(dt_now)[:10])
# Out:
# 2026-01-13
